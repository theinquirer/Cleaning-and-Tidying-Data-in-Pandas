# %%
import pandas as pd

# %%
ebola = pd.read_csv(r'C:/Users/amash/OneDrive/Desktop/cleaningData/country_timeseries.csv')

ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
ebola.head()
# Out:
#          Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0    1/5/2015  289        2776.0            NaN            10030.0
# 1    1/4/2015  288        2775.0            NaN             9780.0
# 2    1/3/2015  287        2769.0         8166.0             9722.0
# 3    1/2/2015  286           NaN         8157.0                NaN
# 4  12/31/2014  284        2730.0         8115.0             9633.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# 2            NaN            NaN                 NaN          NaN         NaN
# 3            NaN            NaN                 NaN          NaN         NaN
# 4            NaN            NaN                 NaN          NaN         NaN
#
#    Deaths_Guinea  Deaths_Liberia  Deaths_SierraLeone  Deaths_Nigeria  \
# ...

# %%
#columns that remian unchanged
ebola_long = pd.melt(ebola,
                    id_vars =['Date', 'Day'])

ebola_long
# Out:
#             Date  Day      variable   value
# 0       1/5/2015  289  Cases_Guinea  2776.0
# 1       1/4/2015  288  Cases_Guinea  2775.0
# 2       1/3/2015  287  Cases_Guinea  2769.0
# 3       1/2/2015  286  Cases_Guinea     NaN
# 4     12/31/2014  284  Cases_Guinea  2730.0
# ...          ...  ...           ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN
# 1948   3/26/2014    4   Deaths_Mali     NaN
# 1949   3/25/2014    3   Deaths_Mali     NaN
# 1950   3/24/2014    2   Deaths_Mali     NaN
# 1951   3/22/2014    0   Deaths_Mali     NaN
#
# [1952 rows x 4 columns]

# %%
'Cases_Guinea'.split('_')
# Out:
# ['Cases', 'Guinea']

# %%
#using str to manipulate the variable column along with split 
#  utlize the str function to split the variable column
v_split = ebola_long['variable'].str.split('_')

# %%
v_split
# Out:
# 0       [Cases, Guinea]
# 1       [Cases, Guinea]
# 2       [Cases, Guinea]
# 3       [Cases, Guinea]
# 4       [Cases, Guinea]
#              ...
# 1947     [Deaths, Mali]
# 1948     [Deaths, Mali]
# 1949     [Deaths, Mali]
# 1950     [Deaths, Mali]
# 1951     [Deaths, Mali]
# Name: variable, Length: 1952, dtype: object

# %%
 type(v_split)
# Out:
# pandas.core.series.Series

# %%
type(v_split[0])
# Out:
# list

# %%
# display the first element in the list
(v_split[0] [0])
# Out:
# 'Cases'

# %%
type(v_split[0] [0])
# Out:
# str

# %%
v_split
# Out:
# 0       [Cases, Guinea]
# 1       [Cases, Guinea]
# 2       [Cases, Guinea]
# 3       [Cases, Guinea]
# 4       [Cases, Guinea]
#              ...
# 1947     [Deaths, Mali]
# 1948     [Deaths, Mali]
# 1949     [Deaths, Mali]
# 1950     [Deaths, Mali]
# 1951     [Deaths, Mali]
# Name: variable, Length: 1952, dtype: object

# %%
v_split.str.get(0)
# Out:
# 0        Cases
# 1        Cases
# 2        Cases
# 3        Cases
# 4        Cases
#          ...
# 1947    Deaths
# 1948    Deaths
# 1949    Deaths
# 1950    Deaths
# 1951    Deaths
# Name: variable, Length: 1952, dtype: object

# %%
v_split.str.get(1)
# Out:
# 0       Guinea
# 1       Guinea
# 2       Guinea
# 3       Guinea
# 4       Guinea
#          ...
# 1947      Mali
# 1948      Mali
# 1949      Mali
# 1950      Mali
# 1951      Mali
# Name: variable, Length: 1952, dtype: object

# %%
ebola_long['stat']= v_split.str.get(0)
ebola_long['country']= v_split.str.get(1)

# %%
ebola_long
# Out:
#             Date  Day      variable   value  status    stat country
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases   Cases  Guinea
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases   Cases  Guinea
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases   Cases  Guinea
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases   Cases  Guinea
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases   Cases  Guinea
# ...          ...  ...           ...     ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths  Deaths    Mali
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths  Deaths    Mali
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths  Deaths    Mali
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths  Deaths    Mali
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths  Deaths    Mali
#
# [1952 rows x 7 columns]

# %%
ebola_long['variable'].str.split('_', expand = True)
# Out:
#            0       1
# 0      Cases  Guinea
# 1      Cases  Guinea
# 2      Cases  Guinea
# 3      Cases  Guinea
# 4      Cases  Guinea
# ...      ...     ...
# 1947  Deaths    Mali
# 1948  Deaths    Mali
# 1949  Deaths    Mali
# 1950  Deaths    Mali
# 1951  Deaths    Mali
#
# [1952 rows x 2 columns]

# %%
ebola_long [['stat_e', 'country_e']] = ebola_long['variable'].str.split('_', expand = True)
ebola_long
# Out:
#             Date  Day      variable   value  status    stat country  stat_e  \
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases   Cases  Guinea   Cases
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases   Cases  Guinea   Cases
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases   Cases  Guinea   Cases
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases   Cases  Guinea   Cases
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases   Cases  Guinea   Cases
# ...          ...  ...           ...     ...     ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
#
#      country_e
# 0       Guinea
# 1       Guinea
# ...

# %%
ebola_long [['stat_e', 'country_e']] = (ebola_long['variable'].str.
                                        split('_', expand = True))
ebola_long
# Out:
#             Date  Day      variable   value  status    stat country  stat_e  \
# 0       1/5/2015  289  Cases_Guinea  2776.0   Cases   Cases  Guinea   Cases
# 1       1/4/2015  288  Cases_Guinea  2775.0   Cases   Cases  Guinea   Cases
# 2       1/3/2015  287  Cases_Guinea  2769.0   Cases   Cases  Guinea   Cases
# 3       1/2/2015  286  Cases_Guinea     NaN   Cases   Cases  Guinea   Cases
# 4     12/31/2014  284  Cases_Guinea  2730.0   Cases   Cases  Guinea   Cases
# ...          ...  ...           ...     ...     ...     ...     ...     ...
# 1947   3/27/2014    5   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1948   3/26/2014    4   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1949   3/25/2014    3   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1950   3/24/2014    2   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
# 1951   3/22/2014    0   Deaths_Mali     NaN  Deaths  Deaths    Mali  Deaths
#
#      country_e
# 0       Guinea
# 1       Guinea
# ...
