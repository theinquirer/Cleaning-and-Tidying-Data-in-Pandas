# %%
import pandas as pd

# %%
billboard = pd.read_csv(r'C:/Users/amash/OneDrive/Desktop/cleaningData/billboard.csv')

billboard
# Out:
#      year            artist                    track        time date.entered  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22:00 AM    2/26/2000
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15:00 AM     9/2/2000
# 2    2000      3 Doors Down               Kryptonite  3:53:00 AM     4/8/2000
# 3    2000      3 Doors Down                    Loser  4:24:00 AM   10/21/2000
# 4    2000          504 Boyz            Wobble Wobble  3:35:00 AM    4/15/2000
# ..    ...               ...                      ...         ...          ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10:00 AM    4/29/2000
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55:00 AM     4/1/2000
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19:00 AM    3/18/2000
# 315  2000     Zombie Nation            Kernkraft 400  3:30:00 AM     9/2/2000
# 316  2000   matchbox twenty                     Bent  4:12:00 AM    4/29/2000
#
# ...

# %%
#columns headers should be a value and not a variable
#diplay a column name week with corresponding rating 
# display week with corresponding values

# %%
billboard_melt =pd.melt(
    billboard,
    id_vars=['year','artist','track', 'date.entered'],
    var_name = 'week',
    value_name ='rating'
)

# %%
#melt consolidate the weeks and rating variable into a single columns
billboard_melt.head()
# Out:
#    year        artist                    track date.entered  week      rating
# 0  2000         2 Pac  Baby Don't Cry (Keep...    2/26/2000  time  4:22:00 AM
# 1  2000       2Ge+her  The Hardest Part Of ...     9/2/2000  time  3:15:00 AM
# 2  2000  3 Doors Down               Kryptonite     4/8/2000  time  3:53:00 AM
# 3  2000  3 Doors Down                    Loser   10/21/2000  time  4:24:00 AM
# 4  2000      504 Boyz            Wobble Wobble    4/15/2000  time  3:35:00 AM

# %%
#display rows and columns respectively
billboard.shape
# Out:
# (317, 81)
